# %%
from pprint import pprint

from AIQSales.Gettoken import LDH_GetAuth 
from AIQSales.GetData import LDH_GetData
from AIQSales.LoadToDB import To_postgres
import pandas as pd

from datetime import datetime

"""

# API Conenction Data
access_token_url="https://api-gw-dev.boehringer-ingelheim.com:8443/api/oauth/token"
client_id = '15aee13f-8bcb-47e8-b77e-e446f8ab175c'
client_secret = '1a897726-3d3e-49d7-942d-780dac43a291'
"""


#API QA
access_token_url = "https://api-gw-qa.boehringer-ingelheim.com:8443/api/oauth/token"
client_id=  "d3efd2d3-1ac0-4374-80c3-7a8205c29947"
client_secret = "dc359cbf-782f-4964-b3ce-81333aab1f71"
    

# Get APi access Token
token =  LDH_GetAuth(access_token_url, client_id, client_secret)
access_token=  token.access_token

print(access_token)
# Out:
# Task exception was never retrieved
# future: <Task finished coro=<main() done, defined at <ipython-input-1-b283e51bf120>:17> exception=AttributeError("'str' object has no attribute 'path'",)>
# Traceback (most recent call last):
#   File "<ipython-input-1-b283e51bf120>", line 26, in main
#     await asyncio.gather(*tasks)
#   File "<ipython-input-1-b283e51bf120>", line 9, in download_coroutine
#     filename = __.path.basename(url)
# AttributeError: 'str' object has no attribute 'path'
# uvG2VpcVbNSPtkOli9g1KJAGqlsWMAkA0eD9uqG1KM0srNvBhMJJ1x
# C:\Users\Dharmandra\Anaconda3\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api-gw-dev.boehringer-ingelheim.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
import requests
"""https://api-gw-dev.boehringer-ingelheim.com:8443\
/sales-data-api/sales-data?business=ah&country=us&modifiedFrom=2020-06-02T14:00:00-05:00&offset=100&limit=100 
"""
customerapi= 'financial-customer-data-api/customers'
business= 'ah'
country= 'us'
modifiedFrom= '2019-06-02T14:00:00-05:00'
modifiedTo= '2020-06-02T14:00:00-05:00'
limit= '100'

# %%
customerfull= []

import requests

for i in range(0,500, 100):
    offset= i

    customersurl = "https://api-gw-dev.boehringer-ingelheim.com:8443/{0}?business={1}&country={2}&modifiedFrom={3}&offset={4}&limit={5}".\
    format(customerapi, business, country, modifiedFrom, offset, limit)

    Customers= requests.get(customersurl, headers={'Authorization': 'Bearer ' + access_token}, verify=True)

    if (Customers.ok and Customers.status_code==200):
        Customers = Customers.json()
        customerfull.append(Customers)
        #return Customers
    else:
        r=  Customers
        message =  "HTTP %i - %s, Message %s" % (r.status_code, r.reason, r.text)
        print(message)
        #return message

# %%
customersurl
# Out:
# 'https://api-gw-dev.boehringer-ingelheim.com:8443/financial-customer-data-api/customers?business=ah&country=us&modifiedFrom=2019-06-02T14:00:00-05:00&offset=400&limit=100'

# %%
cust_list = []

for i in customerfull:
    cust= {}
    for j in i:
        BICustomers.append(j)
        

        

for customer in BICustomers:
    cust= {}
    if len(customer)>0:
        try:
            
            cust['location_id']= customer['shipTo']['id']
            cust['location_status']= customer['shipTo']['status']
            cust['location_type']= customer['shipTo']['type']
            cust['price_list']= customer['shipTo']['salesPriceListId']
            cust['location_name']= customer['shipTo']['name']
            cust['ship_to_address_1']= customer['shipTo']['addressLine1']
            if 'addressLine2' in customer['shipTo']: cust['ship_to_address_2'] = customer['shipTo']['addressLine2']
            else: cust['ship_to_address_2'] = ''
            cust['ship_to_postal']= customer['shipTo']['zipOrPostalCode']
            cust['ship_to_city']= customer['shipTo']['city']
            cust['ship_to_state']= customer['shipTo']['stateCode']
            cust['ship_to_country']= customer['shipTo']['countryName']
            cust['customer_class']= customer['shipTo']['customerClass']
            cust['buying_group']= '' #customer['shipTo']['buying_group']
            cust['self_assigned_identifier']= '' #customer['shipTo']['self_assigned_identifier']
            
            if 'id' in customer['billTo']: cust['bill_to_location_id'] = customer['billTo']['id']
            else: cust['bill_to_location_id'] = ''
                
            cust['ship_to_location_id']= customer['shipTo']['id']
            cust['sold_to_location_id']= customer['soldTo']['id']
            
            if 'id' in customer['billTo']: cust['payer_location_id'] = customer['billTo']['id']
            else: cust['payer_location_id'] = ''
            
            cust['inserted_date']=datetime.now().date()
            cust['inserted_by']= 'app_ldh_rw'
            cust['updated_date']=datetime.now().date()
            cust['updated_by']='app_ldh_rw'

                
        except KeyError as e:
            print( "Error Message: location %s missing field %s" % (customer['shipTo']['id'], e))
            
        
    cust_list.append(cust)

# %%
cust_list = []
for customer in BICustomers:
    cust= {}
    if len(customer)>0:
        try:
            
            cust['location_id']= customer['shipTo']['id']
            cust['location_status']= customer['shipTo']['status']
            cust['location_type']= customer['shipTo']['type']
            cust['price_list']= customer['shipTo']['salesPriceListId']
            cust['location_name']= customer['shipTo']['name']
            cust['ship_to_address_1']= customer['shipTo']['addressLine1']
            if 'addressLine2' in customer['shipTo']: cust['ship_to_address_2'] = customer['shipTo']['addressLine2']
            else: cust['ship_to_address_2'] = ''
            cust['ship_to_postal']= customer['shipTo']['zipOrPostalCode']
            cust['ship_to_city']= customer['shipTo']['city']
            cust['ship_to_state']= customer['shipTo']['stateCode']
            cust['ship_to_country']= customer['shipTo']['countryName']
            cust['customer_class']= customer['shipTo']['customerClass']
            cust['buying_group']= '' #customer['shipTo']['buying_group']
            cust['self_assigned_identifier']= '' #customer['shipTo']['self_assigned_identifier']
            
            if 'id' in customer['billTo']: cust['bill_to_location_id'] = customer['billTo']['id']
            else: cust['bill_to_location_id'] = ''
                
            cust['ship_to_location_id']= customer['shipTo']['id']
            cust['sold_to_location_id']= customer['soldTo']['id']
            
            if 'id' in customer['billTo']: cust['payer_location_id'] = customer['billTo']['id']
            else: cust['payer_location_id'] = ''
            
            cust['inserted_date']=datetime.now().date()
            cust['inserted_by']= 'app_ldh_rw'
            cust['updated_date']=datetime.now().date()
            cust['updated_by']='app_ldh_rw'

                
        except KeyError as e:
            print( "Error Message: location %s missing field %s" % (customer['shipTo']['id'], e))
            
        
    cust_list.append(cust)

# %%
import pandas as pd
df = pd.DataFrame(cust_list)

# %%
df.head()
# Out:
#   location_id  location_status location_type                       price_list  \
# 0     1000016                0          Pets           LIM DOM MVC Price List
# 1     1000020                1   Pets-Equine           LIM DOM MVC Price List
# 2     1000024                1          Pets  LIM DOM Vaccine Pref Price List
# 3     1000037                0    Unassigned           LIM DOM MVC Price List
# 4     1000041                1   Pets-Equine           LIM DOM MVC Price List
#
#                     location_name   ship_to_address_1 ship_to_address_2  \
# 0                      ZOETIS INC      333 PORTAGE RD     BLDG 300 DOCK
# 1  RIVER VALLEY VETERINARY CLINIC         395 MAIN ST
# 2     SEVEN LOCKS ANIMAL HOSPITAL   7817 TUCKERMAN LN
# 3                WARD RIVER RANCH       38568 WARD DR
# 4      ALL PAWS VETERINARY CLINIC  4245 W CARDINAL DR
#
#   ship_to_postal ship_to_city ship_to_state  ... buying_group  \
# 0          49007    KALAMAZOO            MI  ...
# ...

# %%
df['location_id'].nunique()
# Out:
# 500

# %%
def path_exists(path,sc):
    # spark is a SparkSession
    #sc = spark.sparkContext
    fs = sc._jvm.org.apache.hadoop.fs.FileSystem.get( sc._jvm.java.net.URI.create("s3://" + path.split("/")[2]), sc._jsc.hadoopConfiguration())
    return fs.exists(sc._jvm.org.apache.hadoop.fs.Path(path))

# %%
import resource
#!pip install resource
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-a92ae08ea4b6> in <module>()
# ----> 1 import resource
#
# ModuleNotFoundError: No module named 'resource'

# %%
import argparse
import asyncio
import sys
#import resource
from aiohttp import ClientSession
from functools import partial
import time
import json
import aiofiles
import pandas as pd
import logging
import os
import requests
import json

from datetime import datetime

def create_job_paths(jobname):
    today =  datetime.now().strftime("%d-%m-%y")
    main_path="./"
    os.chdir(main_path)
    os.makedirs("output/{}/{}/".format(jobname,today),exist_ok=True)
    os.makedirs("logs/"+jobname ,exist_ok=True)
    destination_path=main_path+"output/{}/{}/".format(jobname,today)
    log_path=main_path+"logs/"+jobname+"/Log_{0}.log".format(today)
    return log_path, destination_path

jobname = "customer_Load"
log_path, destination_path= create_job_paths(jobname)

print('log_path' ,log_path)

print('destination_path' ,destination_path)

logtime =  datetime.now().strftime("%d/%m/%Y %H:%M:%S")

logger = logging.getLogger("ETL Job logging start for job:{0} on time:{1}".format(jobname,logtime))

logging.basicConfig(filename=log_path,format='%(name)s - %(levelname)s - %(asctime)s - %(message)s - %(lineno)d', datefmt="%d-%b-%y %H:%M:%S",level=logging.INFO)
# Out:
# log_path ./logs/customer_Load/Log_21-01-21.log
# destination_path ./output/customer_Load/21-01-21/

# %%
responses = 0
requests_sent = 0
error_counter = 0

def get_mem():
    return resource.getrusage(resource.RUSAGE_SELF).ru_maxrss/1000000

async def run(session, number_of_requests, concurrent_limit):
    base_url = "http://localhost:8888/{}"
    tasks = []
    sem = asyncio.Semaphore(concurrent_limit)

    async def fetch(i):
        global responses
        global requests_sent
        
        """
        index=i[0]
        print(index)
        url=i[1]["url"]
        date=i[1]["Date"]
        zipcode=i[1]["Zip Code"]
        filename=i[1]["filename"]
        """
        
        
        customerapi= 'financial-customer-data-api/customers'
        business= 'ah'
        country= 'us'
        modifiedFrom= '2019-06-02T14:00:00-05:00'
        modifiedTo= '2020-06-02T14:00:00-05:00'
        
        offset= i
        limit= '100'
        
        lastLimit= offset+100
        filename =  "Customer_offset_from_{0}_to_{1}".format(offset, lastLimit )
        
        customers = "https://api-gw-dev.boehringer-ingelheim.com:8443/{0}?business={1}&country={2}&modifiedFrom={3}&offset={4}&limit={5}".\
        format(customerapi, business, country, modifiedFrom, offset, limit)
        
        #url="http://localhost:8888/1"
        await asyncio.sleep(1)
        async with session.get(customers) as response:
            requests_sent += 1
           
            response = await response.text()
            for customer in BICustomers:
                
                cust= {}
                if len(customer)>0:
                    try:
                        cust['location_id']= customer['shipTo']['id']
                        cust['location_status']= customer['shipTo']['status']
                        cust['location_type']= customer['shipTo']['type']
                        cust['price_list']= customer['shipTo']['salesPriceListId']
                        cust['location_name']= customer['shipTo']['name']
                        cust['ship_to_address_1']= customer['shipTo']['addressLine1']
                        if 'addressLine2' in customer['shipTo']: cust['ship_to_address_2'] = customer['shipTo']['addressLine2']
                        else: cust['ship_to_address_2'] = ''
                        cust['ship_to_postal']= customer['shipTo']['zipOrPostalCode']
                        cust['ship_to_city']= customer['shipTo']['city']
                        cust['ship_to_state']= customer['shipTo']['stateCode']
                        cust['ship_to_country']= customer['shipTo']['countryName']
                        cust['customer_class']= customer['shipTo']['customerClass']
                        cust['buying_group']= '' #customer['shipTo']['buying_group']
                        cust['self_assigned_identifier']= '' #customer['shipTo']['self_assigned_identifier']

                        if 'id' in customer['billTo']: cust['bill_to_location_id'] = customer['billTo']['id']
                        else: cust['bill_to_location_id'] = ''

                        cust['ship_to_location_id']= customer['shipTo']['id']
                        cust['sold_to_location_id']= customer['soldTo']['id']

                        if 'id' in customer['billTo']: cust['payer_location_id'] = customer['billTo']['id']
                        else: cust['payer_location_id'] = ''

                        cust['inserted_date']=datetime.now().date()
                        cust['inserted_by']= 'app_ldh_rw'
                        cust['updated_date']=datetime.now().date()
                        cust['updated_by']='app_ldh_rw'
                        
                    except KeyError as e:
                        print( "Error Message: location %s missing field %s" % (customer['shipTo']['id'], e))


                    cust_list.append(cust)
    
            async with aiofiles.open("{}/{}.json".format(destination_path,filename),"w") as temp_f:
                logger.info("File write completed for index {}".format(index))
                
                await temp_f.write(cust_list)
                responses += 1
                #print(response)
            
            sem.release()
            
    
    start_index=0
    end_index=None
    
    for i in range(0,500, 100):
        logger.info("offeset Index position from {0} to {1}".format(i, i+100))
        #logger.info("Remaining tasks: {}".format(len(tasks)))
        await sem.acquire()
        
        #[await sem.acquire() for x in range(concurrent_limit+1)]
        #url = base_url.format(i)
        print('heloo')
        task = asyncio.ensure_future(fetch(i))
        task.add_done_callback(tasks.remove)
        tasks.append(task)
        #await asyncio.wait(tasks)
    await asyncio.wait(tasks)

    
# starting main with async
async def main(number_of_requests, concurrent_limit):
    async with ClientSession() as session:
        responses = await asyncio.ensure_future(run(session, number_of_requests, concurrent_limit))
    
    #print(dir(session_dummy))
    #async with ClientSession() as session:
        #responses = await asyncio.ensure_future(run(session, number_of_requests, concurrent_limit))
    return

# func to handle erorr and log it
def error_handler(loop,e):
    global error_counter
    
    logger.info("Inside Error Handler")
    logger.error("{}".format(str(e)),exc_info=0)
    pending = asyncio.Task.all_tasks()
    pending=list(pending)
    logger.error("Pending tasks before{}".format(len(pending)))
    for i in pending:
        error=i._exception
        logger.error("{}".format(str(error)))
        logger.info("Status: {}".format(i._state))
        try:
            pending.remove(i)
            
        except Exception as e:
            pass

    logger.error("Pending tasks after {}".format(len(pending)))
    
    try:
        loop.run_until_complete(asyncio.gather(*((task) for task in pending)))
        logger.info("Gracefully shutting down")
    except Exception as e:
        if error_counter <= 25:
            error_counter += 1
            error_handler(loop,e)
        else:
            pending = asyncio.Task.all_tasks()
            [task.cancel for task in pending]
            logger.info("Error counter reached peak: {}".format(error_counter))
            logger.error("Shutting down: {} tasks".format(len(pending)),exc_info=0)
            logger.error("Cancelled all pending tasks",exc_info=0)
            logger.info("Gracefully shutting down")

# %%
if __name__ == '__main__':
    
    """
    run: python client.py -n 1000 -c 100
    """
    
    start=time.time()
    
    number_of_requests = 1
    concurrent_limit = 2
    
    try:
        print("Destination Path: {}".format(destination_path))
        print("Log Path: {}".format(log_path))
        loop = asyncio.get_event_loop()
        loop.run_until_complete(main(number_of_requests, concurrent_limit))
        
    except KeyboardInterrupt:
        logger.error("{}".format(str("KeyboardInterrupt"),exc_info=0))
        
        pending = asyncio.Task.all_tasks()
        
        [task.cancel() for task in pending]
        logger.error("Shutting down: {} tasks".format(len(pending)),exc_info=0)
        logger.error("Cancelled all pending tasks",exc_info=0)
        #loop.run_until_complete(asyncio.gather(*((task) for task in pending)))

    except Exception as e:
        error_handler(loop,e)

    loop.stop()
    
    end=time.time()
    
    print("Destination Path: {}".format(destination_path))
    print("Log Path: {}".format(log_path))
    logger.info("Number of requests sent: {}".format(requests_sent))
    logger.info("Number of records processed: {}".format(responses))
    logger.info("Time taken {}".format(end-start))
    print("Time taken {}".format(end-start))
# Out:
# Destination Path: ./output/customer_Load/21-01-21/
# Log Path: ./logs/customer_Load/Log_21-01-21.log
# Destination Path: ./output/customer_Load/21-01-21/
# Log Path: ./logs/customer_Load/Log_21-01-21.log
# Time taken 0.02294135093688965

# %%
"""
import argparse
import asyncio
import sys
import resource
from aiohttp import ClientSession
from functools import partial
import time
import json
import aiofiles
import pandas as pd
import logging
import os
import requests
import json



def create_paths(source_file):
    state,year=os.path.basename(source_file).replace(".parquet","").split("_")
    #main_path="/home/smart/weather_analytics_2020/home/smartml/weather_official/2020 PoC inside BI Env/asyncio_recap/dummy_testrun/"
    main_path="/home/smart/weather_analytics_2020/home/smartml/weather_official/2020 PoC inside BI Env/Weather_data/"
    os.chdir(main_path)
    os.makedirs("output/{}/{}/".format(state,year),exist_ok=True)
    os.makedirs("logs/",exist_ok=True)
    destination_path=main_path+"output/{}/{}/".format(state,year)
    log_path=main_path+"logs/main.log"
    return state,year,main_path,destination_path,log_path

#initializing file

#source_file = "/home/smart/weather_analytics_2020/home/smartml/weather_official/2020 PoC inside BI Env/zip_with_url/connecticut|missed_2017.parquet"
import sys
source_file = sys.argv[1]
state,year,main_path,destination_path,log_path = create_paths(source_file)


logger = logging.getLogger("{}_{}".format(state,year))
logging.basicConfig(filename=log_path,format='%(name)s - %(levelname)s - %(asctime)s - %(message)s - %(lineno)d', datefmt="%d-%b-%y %H:%M:%S",level=logging.INFO)



df=pd.read_parquet(source_file,columns=["Zip Code","Date","url","filename"])
nrows=df.shape[0]
start=time.time()

responses = 0
requests_sent = 0
error_counter = 0

def get_mem():
    return resource.getrusage(resource.RUSAGE_SELF).ru_maxrss/1000000

async def run(session, number_of_requests, concurrent_limit):
    base_url = "http://localhost:8888/{}"
    tasks = []
    sem = asyncio.Semaphore(concurrent_limit)

    async def fetch(i):
        global responses
        global requests_sent

        index=i[0]
        print(index)
        url=i[1]["url"]
        date=i[1]["Date"]
        zipcode=i[1]["Zip Code"]
        filename=i[1]["filename"]
        #url="http://localhost:8888/1"
        await asyncio.sleep(1)
        async with session.get(url) as response:
            requests_sent += 1
           
            response = await response.text()
            async with aiofiles.open("{}/{}.json".format(destination_path,filename),"w") as temp_f:
                logger.info("File write completed for index {}".format(index))
                
                await temp_f.write(response)
                responses += 1
                #print(response)
            
            sem.release()
            
        

    start_index=0
    end_index=None
    for i in df.iloc[start_index:end_index].iterrows():
        logger.info("Index position {}".format(i[0]))
        logger.info("Remaining tasks: {}".format(len(tasks)))
        await sem.acquire()
        
        #[await sem.acquire() for x in range(concurrent_limit+1)]
        url = base_url.format(i)
        task = asyncio.ensure_future(fetch(i))
        task.add_done_callback(tasks.remove)
        tasks.append(task)

  
        
        

        #await asyncio.wait(tasks)

    await asyncio.wait(tasks)


async def main(number_of_requests, concurrent_limit):
    async with ClientSession() as session:
        responses = await asyncio.ensure_future(run(session, number_of_requests, concurrent_limit))
    
    #print(dir(session_dummy))
    #async with ClientSession() as session:
        #responses = await asyncio.ensure_future(run(session, number_of_requests, concurrent_limit))
    return


def error_handler(loop,e):
    global error_counter
    
    logger.info("Inside Error Handler")
    logger.error("{}".format(str(e)),exc_info=0)
    pending = asyncio.Task.all_tasks()
    pending=list(pending)
    logger.error("Pending tasks before{}".format(len(pending)))
    for i in pending:
        error=i._exception
        logger.error("{}".format(str(error)))
        logger.info("Status: {}".format(i._state))
        try:
            pending.remove(i)
            
        except Exception as e:
            pass

    logger.error("Pending tasks after {}".format(len(pending)))
    try:
        loop.run_until_complete(asyncio.gather(*((task) for task in pending)))
        logger.info("Gracefully shutting down")
    except Exception as e:
        if error_counter <= 25:
            error_counter += 1
            error_handler(loop,e)
        else:
            pending = asyncio.Task.all_tasks()
            [task.cancel for task in pending]
            logger.info("Error counter reached peak: {}".format(error_counter))
            logger.error("Shutting down: {} tasks".format(len(pending)),exc_info=0)
            logger.error("Cancelled all pending tasks",exc_info=0)
            logger.info("Gracefully shutting down")


    
if __name__ == '__main__':
    """
    #run: python client.py -n 1000 -c 100
    """
    
    number_of_requests = 1000
    concurrent_limit = 50
    print("number_of_requests: {}, concurrent_limit: {}".format(number_of_requests, concurrent_limit))
    url="https://hooks.slack.com/services/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"
    headers={"Content-type": "application/json"}
    data=json.dumps({"text": "Process Started {} {}".format(state,year)})
    requests.post(url=url,data=data,headers=headers)

    try:
        print("Destination Path: {}".format(destination_path))
        print("Log Path: {}".format(log_path))
        loop = asyncio.get_event_loop()
        loop.run_until_complete(main(number_of_requests, concurrent_limit))
    except KeyboardInterrupt:
        logger.error("{}".format(str("KeyboardInterrupt"),exc_info=0))
        
        pending = asyncio.Task.all_tasks()
        
        [task.cancel() for task in pending]
        logger.error("Shutting down: {} tasks".format(len(pending)),exc_info=0)
        logger.error("Cancelled all pending tasks",exc_info=0)
        #loop.run_until_complete(asyncio.gather(*((task) for task in pending)))

    except Exception as e:
        error_handler(loop,e)

    loop.stop()
    
    url="https://hooks.slack.com/services/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"
    headers={"Content-type": "application/json"}
    data=json.dumps({"text": "Process Completed {} {}".format(state,year)})
    requests.post(url=url,data=data,headers=headers)
    end=time.time()
    print("Destination Path: {}".format(destination_path))
    print("Log Path: {}".format(log_path))
    logger.info("Number of requests sent: {}".format(requests_sent))
    logger.info("Number of records processed: {}".format(responses))
    logger.info("Time taken {}".format(end-start))
    print("Time taken {}".format(end-start))
    
    
"""
# Out:
# do

# %%
import aiohttp
import asyncio
import async_timeout
import os
 
async def download_coroutine(session, url):
    with async_timeout.timeout(10):
        async with session.get(url) as response:
            filename = __.path.basename(url)
            with open(________, 'wb') as f_handle:
                while True:
                    chunk = await response.content.read(1024)
                    if not chunk:
                        break
                    f_handle.write(_____)
            return await response.release()
        
async def main(loop):
    urls = ["http://www.irs.gov/pub/irs-pdf/f1040.pdf",
        "http://www.irs.gov/pub/irs-pdf/f1040a.pdf",
        "http://www.irs.gov/pub/irs-pdf/f1040ez.pdf",
        "http://www.irs.gov/pub/irs-pdf/f1040es.pdf",
        "http://www.irs.gov/pub/irs-pdf/f1040sb.pdf"]
 
    async with aiohttp.ClientSession(loop=loop) as session:
        tasks = [download_coroutine(session, url) for url in urls]
        await asyncio.gather(*tasks)


if __name__ == '__main__':
    loop = asyncio.get_event_loop()
    loop.run_until_complete(main(loop))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-b283e51bf120> in <module>()
#      29 if __name__ == '__main__':
#      30     loop = asyncio.get_event_loop()
# ---> 31     loop.run_until_complete(main(loop))
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     453         future.add_done_callback(_run_until_complete_cb)
#     454         try:
# --> 455             self.run_forever()
#     456         except:
#     457             if new_task and future.done() and not future.cancelled():
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_forever(self)
#     407         self._check_closed()
#     408         if self.is_running():
# --> 409             raise RuntimeError('This event loop is already running')
#     410         if events._get_running_loop() is not None:
#     411             raise RuntimeError(
#
# ...
